# %%
import json

with open('/home/nvidia/material_classification/scripts/libs/ml-dms-dataset/preparation_outcomes.json', 'r') as file:
    data = json.load(file)

data.keys()
# Out:
# dict_keys(['prepared image found', 'original image not found', 'image copied', 'image resized', 'image not processed', 'documentation'])

# %%
for key, values in data.items():
    print(f"{key}: {len(values)}")
# Out:
# prepared image found: 0
# original image not found: 3130
# image copied: 22221
# image resized: 19175
# image not processed: 31
# documentation: 282
